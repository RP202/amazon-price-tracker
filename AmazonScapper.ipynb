# %%
# libraries to impot
from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime

# %%
# CONNECTIGN THE AMAZON PRODUCT

# %%
URL = 'https://www.amazon.in/Travel-Toiletry-Cosmetic-Organizer-Storage/dp/B0DKY4Q4X3'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36"
}

page = requests.get(URL, headers=headers)

soup1 = BeautifulSoup(page.content, "html.parser")
soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
title = soup2.find(id="productTitle").get_text()
price = soup2.find(class_="a-price-whole").get_text()

import datetime
today = datetime.date.today()

print(title)
print(price)
print(today)
# Out:
#            APOPHIS Travel Makeup Pouch Toiletry Bag Cosmetic Organizer Bag for Women and Girls Toiletry Storage Kit (White MINI)
#
#
#                              188
#
#                               .
#
#
# 2026-04-20

# %%
import csv


header = ['Title','Price','Date']
data = [title,price,today]

# type(data) -> list

with open('AmazonScapper.csv','w',newline='',encoding='UTF-8') as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\KIIT0001\Desktop\jupyter\AmazonScapper.csv")
print(df)
# Out:
#                                                Title  \
# 0  \n           APOPHIS Travel Makeup Pouch Toile...
#
#                                                Price        Date
# 0  \n                             188\n          ...  2026-04-20

# %%
# appending data
with open('AmazonScapper.csv','a+',newline='',encoding='UTF-8') as f:
    writer=csv.writer(f)
    writer.writerow(data)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\KIIT0001\Desktop\jupyter\AmazonScapper.csv")
print(df)
# Out:
#                                                Title  \
# 0  \n           APOPHIS Travel Makeup Pouch Toile...
# 1  \n           APOPHIS Travel Makeup Pouch Toile...
#
#                                                Price        Date
# 0  \n                             188\n          ...  2026-04-20
# 1  \n                             188\n          ...  2026-04-20

# %%
import requests
from bs4 import BeautifulSoup
import datetime
import csv

def check_price():
    URL = 'https://www.amazon.in/Travel-Toiletry-Cosmetic-Organizer-Storage/dp/B0DKY4Q4X3'

    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36"
}

    page = requests.get(URL, headers=headers)
    soup = BeautifulSoup(page.content, "html.parser")

    title = soup.find(id="productTitle").get_text()
    price = soup.find(class_="a-price-whole").get_text()

    today = datetime.date.today()
    data = [title, price, today]

    with open('AmazonScapper.csv', 'a', newline='', encoding='utf-8') as f:
        writer = csv.writer(f)
        writer.writerow(data)
    if(price<100):
     send_mail()

# %%
import smtplib

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()
    server.login('rupalikth@gmail.com', 'xxxxxxxxx')

    subject = 'The pouch price is reduced'
    body = 'Hey! Rupali the pouch you have been eyeing on is available in lower price'
    msg = f'Subject: {subject}\n\n{body}'

    server.sendmail(
        'rupalikth@gmail.com',
        'rupalikth@gmail.com',
        msg
    )

    server.quit()

# %%
while(True):
    check_price()
    time.sleep(86400)

    # jab tk roke na outpu nhi ayega
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[55], line 2
#       1 while(True):
# ----> 2     check_price()
#       3     time.sleep(86400)
#       5     # jab tk roke na outpu nhi ayega
#
# Cell In[50], line 22, in check_price()
#      19 today = datetime.date.today()
#      20 data = [title, price, today]
# ---> 22 with open('AmazonScapper.csv', 'a', newline='', encoding='utf-8') as f:
#      23     writer = csv.writer(f)
#      24     writer.writerow(data)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\KIIT0001\Desktop\jupyter\AmazonScapper.csv")
print(df)
# Out:
#                                                 Title  \
# 0   \n           APOPHIS Travel Makeup Pouch Toile...
# 1   \n           APOPHIS Travel Makeup Pouch Toile...
# 2           APOPHIS Travel Makeup Pouch Toiletry B...
# 3           APOPHIS Travel Makeup Pouch Toiletry B...
# 4           APOPHIS Travel Makeup Pouch Toiletry B...
# 5           APOPHIS Travel Makeup Pouch Toiletry B...
# 6           APOPHIS Travel Makeup Pouch Toiletry B...
# 7           APOPHIS Travel Makeup Pouch Toiletry B...
# 8           APOPHIS Travel Makeup Pouch Toiletry B...
# 9           APOPHIS Travel Makeup Pouch Toiletry B...
# 10          APOPHIS Travel Makeup Pouch Toiletry B...
# 11          APOPHIS Travel Makeup Pouch Toiletry B...
# 12          APOPHIS Travel Makeup Pouch Toiletry B...
# 13          APOPHIS Travel Makeup Pouch Toiletry B...
# 14          APOPHIS Travel Makeup Pouch Toiletry B...
# 15          APOPHIS Travel Makeup Pouch Toiletry B...
# ...
